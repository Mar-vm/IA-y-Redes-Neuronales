# %% [markdown]
# # PlantVillage — Enfermedades plantas
# ### Clasificacion con CNN · ActividadFinal · Dataset #3
#
# **Modelo automatico:** `efficientnet_b4`
#
# ---
# **Entorno:** Local Windows/Linux/Mac
#
# ### Instrucciones
# 1. Esta celda ya tiene el dataset configurado — no cambies `DATASET_ID`
# 2. Verifica que tienes PyTorch instalado
# 3. Ajusta `ZIP_LOCAL_PATH` a tu archivo ZIP
# 4. Ejecuta todas las celdas en orden

# %% [markdown]
# ---
# ## CELDA 0 — Configuracion (ya configurada para este proyecto)

# %%
# Configuracion especifica para: PlantVillage — Enfermedades plantas
# NO cambies DATASET_ID

ENTORNO    = 'local'
DATASET_ID = 3  # PlantVillage — Enfermedades plantas

# CAMBIA ESTAS DOS RUTAS
ZIP_LOCAL_PATH  = r'C:\Users\tuusuario\Descargas\enfermedades_plantas.zip'
BASE_PATH_LOCAL = r'C:\Users\tuusuario\enfermedades_plantas'

# Puedes modificar estos hiperparametros
MODEL_OVERRIDE = None   # None = automatico (efficientnet_b4)
BATCH_OVERRIDE = None
EPOCHS         = 30
LR             = 3e-4
PATIENCE       = 7
SEED           = 42
VAL_SIZE       = 0.15
TEST_SIZE      = 0.15

print('Configuracion lista')
print('  Dataset: #3 — PlantVillage — Enfermedades plantas')
print('  Modelo : efficientnet_b4')
print('  ZIP    :', ZIP_LOCAL_PATH)
print('  Output :', BASE_PATH_LOCAL)

# %% [markdown]
# ---
# ## Celdas 1 al 13 — Copia desde ActividadFinal.ipynb
#
# Copia las celdas 1-13 del archivo `_shared/ActividadFinal_Colab.ipynb`
# (o `ActividadFinal_Local.ipynb` si entrenas en local).
# Solo la CELDA 0 de arriba es especifica de este proyecto.
#
# ### Resumen rapido de las 13 celdas
#
# | Celda | Accion |
# |---|---|
# | 1 | Instalacion e imports |
# | 2 | Carga y normalizacion automatica del ZIP |
# | 2b | Diagnostico (solo si CELDA 2 fallo) |
# | 3 | Analisis visual del dataset |
# | 4 | Augmentacion y DataLoaders |
# | 5 | Modelo — transfer learning |
# | 6 | Entrenamiento con early stopping |
# | 7 | Curvas de entrenamiento |
# | 8 | Evaluacion en test set |
# | 9 | Test visual — predicciones del test set |
# | 10A | Test con imagen aleatoria |
# | 10B | Test con tu propia imagen |
# | 11 | Exportar modelo (.pth + .onnx) |
# | 12 | Guardar resultados |
# | 13 | Resumen final |
